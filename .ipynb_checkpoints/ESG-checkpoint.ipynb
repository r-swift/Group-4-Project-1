# %% [markdown]
# # ESG Ratings and Grades
# ## Do more highly rated or graded companies perform better
#
# ---
#
# ## http://esgcompare.org/
#
# https://www.kaggle.com/datasets/alistairking/public-company-esg-ratings-dataset

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import sem
from scipy.stats import linregress

# data file paths, including both original and cleaned/updated dataset
original_esg_data_path = "csv_files/data.csv"
esg_complete_path = "csv_files/esg_complete.csv"


# Converting csv to dataframe
esg_data = pd.read_csv(original_esg_data_path)
esg_complete = pd.read_csv(esg_complete_path)

# Displaying the original kaggle dataset for preview
esg_data.head()
# Out:
#   ticker                           name currency  \
# 0    dis                 Walt Disney Co      USD
# 1     gm              General Motors Co      USD
# 2    gww                WW Grainger Inc      USD
# 3    mhk          Mohawk Industries Inc      USD
# 4    lyv  Live Nation Entertainment Inc      USD
#
#                         exchange                            industry  \
# 0  NEW YORK STOCK EXCHANGE, INC.                               Media
# 1  NEW YORK STOCK EXCHANGE, INC.                         Automobiles
# 2  NEW YORK STOCK EXCHANGE, INC.  Trading Companies and Distributors
# 3  NEW YORK STOCK EXCHANGE, INC.                   Consumer products
# 4  NEW YORK STOCK EXCHANGE, INC.                               Media
#
#                                                 logo  \
# 0  https://static.finnhub.io/logo/ef50b4a2b263c84...
# 1  https://static.finnhub.io/logo/9253db78-80c9-1...
# 2  https://static.finnhub.io/logo/f153dcda-80eb-1...
# 3  https://static.finnhub.io/logo/26868a62-80ec-1...
# 4  https://static.finnhub.io/logo/1cd144d2-80ec-1...
#
#                                      weburl environment_grade  \
# 0         https://thewaltdisneycompany.com/                 A
# 1                       https://www.gm.com/                 A
# 2                 https://www.grainger.com/                 B
# 3                    https://mohawkind.com/                 A
# 4  https://www.livenationentertainment.com/               BBB
#
#   environment_level social_grade  ... governance_grade governance_level  \
# 0              High           BB  ...               BB           Medium
# 1              High           BB  ...                B           Medium
# 2            Medium           BB  ...                B           Medium
# 3              High            B  ...               BB           Medium
# 4              High           BB  ...                B           Medium
#
#   environment_score  social_score  governance_score  total_score  \
# 0               510           316               321         1147
# 1               510           303               255         1068
# 2               255           385               240          880
# 3               570           298               303         1171
# 4               492           310               250         1052
#
#    last_processing_date total_grade total_level      cik
# 0            19-04-2022         BBB        High  1744489
# 1            17-04-2022         BBB        High  1467858
# 2            19-04-2022          BB      Medium   277135
# 3            18-04-2022         BBB        High   851968
# 4            18-04-2022         BBB        High  1335258
#
# [5 rows x 21 columns]

# %%
#Sorting the original dataframe by highest ESG total score and showing the top 10 results

top_companies = esg_data.sort_values("total_score", ascending=False)
top_companies.head(10)

#maybe for sake of slide we drop: currency, exchange, industry, logo, etc.
# Out:
#     ticker                            name currency  \
# 452    cop                  Conocophillips      USD
# 176   msft                  Microsoft Corp      USD
# 302    eix            Edison International      USD
# 18    abnb                      Airbnb Inc      USD
# 250    apd  Air Products and Chemicals Inc      USD
# 137   amzn                  Amazon.com Inc      USD
# 487    nem             Newmont Corporation      USD
# 195    pep                     PepsiCo Inc      USD
# 494    exc                     Exelon Corp      USD
# 372    pxd    Pioneer Natural Resources Co      USD
#
#                           exchange                        industry  \
# 452  NEW YORK STOCK EXCHANGE, INC.                          Energy
# 176     NASDAQ NMS - GLOBAL MARKET                      Technology
# 302  NEW YORK STOCK EXCHANGE, INC.                       Utilities
# 18      NASDAQ NMS - GLOBAL MARKET  Hotels Restaurants and Leisure
# 250  NEW YORK STOCK EXCHANGE, INC.                       Chemicals
# 137     NASDAQ NMS - GLOBAL MARKET                          Retail
# 487  NEW YORK STOCK EXCHANGE, INC.               Metals and Mining
# 195     NASDAQ NMS - GLOBAL MARKET                       Beverages
# 494     NASDAQ NMS - GLOBAL MARKET                       Utilities
# 372  NEW YORK STOCK EXCHANGE, INC.                          Energy
#
#                                                   logo  \
# 452  https://static.finnhub.io/logo/aacfcb5e-80eb-1...
# 176  https://static.finnhub.io/logo/25e313016e9fac0...
# 302  https://static.finnhub.io/logo/cbccd574-80eb-1...
# 18   https://static2.finnhub.io/file/publicdatany/f...
# 250  https://static.finnhub.io/logo/74581b6e-80eb-1...
# 137  https://static.finnhub.io/logo/967bf7b0-80df-1...
# 487  https://static.finnhub.io/logo/39e32600-80ec-1...
# 195  https://static2.finnhub.io/file/publicdatany/f...
# 494  https://static.finnhub.io/logo/d63a05d0-80eb-1...
# 372  https://static.finnhub.io/logo/5d0d741c-80ec-1...
#
#                               weburl environment_grade environment_level  \
# 452   http://www.conocophillips.com/                AA         Excellent
# 176  https://www.microsoft.com/en-us                AA         Excellent
# 302          https://www.edison.com/                AA         Excellent
# 18         https://www.airbnb.co.in/                 A              High
# 250     https://www.airproducts.com/                AA         Excellent
# 137          https://www.amazon.com/                AA         Excellent
# 487             https://newmont.com/                AA         Excellent
# 195         https://www.pepsico.com/                AA         Excellent
# 494      https://www.exeloncorp.com/                AA         Excellent
# 372             https://www.pxd.com/                AA         Excellent
#
#     social_grade  ... governance_grade governance_level environment_score  \
# 452            A  ...               BB           Medium               687
# 176          BBB  ...               BB           Medium               715
# 302            A  ...               BB           Medium               700
# 18             A  ...              BBB             High               505
# 250          BBB  ...               BB           Medium               700
# 137           BB  ...              BBB             High               668
# 487           BB  ...               BB           Medium               675
# 195           BB  ...               BB           Medium               719
# 494          BBB  ...               BB           Medium               694
# 372          BBB  ...               BB           Medium               700
#
#      social_score  governance_score  total_score  last_processing_date  \
# 452           544               305         1536            16-04-2022
# 176           443               375         1533            27-04-2022
# 302           513               315         1528            17-04-2022
# 18            570               400         1475            10-06-2022
# 250           442               300         1442            16-04-2022
# 137           305               460         1433            16-04-2022
# 487           389               355         1419            18-04-2022
# 195           340               358         1417            18-04-2022
# 494           403               316         1413            17-04-2022
# 372           412               300         1412            18-04-2022
#
#     total_grade total_level      cik
# 452           A        High  1163165
# 176           A        High   789019
# 302           A        High   827052
# 18            A        High  1559720
# 250           A        High     2969
# 137           A        High  1018724
# 487           A        High  1164727
# 195           A        High    77476
# 494           A        High  1109357
# 372           A        High  1038357
#
# [10 rows x 21 columns]

# %%
bottom_companies = esg_data.sort_values("total_score", ascending=True)
bottom_companies.head(10)
# Out:
#     ticker                              name currency  \
# 655   pola                   Polar Power Inc      USD
# 704    gva          Granite Construction Inc      USD
# 228   zion           Zions Bancorporation NA      USD
# 76    afaq               AF Acquisition Corp      USD
# 303    glw                       Corning Inc      USD
# 395    tel               TE Connectivity Ltd      USD
# 396    tfx                      Teleflex Inc      USD
# 595     xl                     XL Fleet Corp      USD
# 72    aese  Allied Esports Entertainment Inc      USD
# 313     ko                      Coca-Cola Co      USD
#
#                           exchange                        industry  \
# 655     NASDAQ NMS - GLOBAL MARKET            Electrical Equipment
# 704  NEW YORK STOCK EXCHANGE, INC.                    Construction
# 228     NASDAQ NMS - GLOBAL MARKET                         Banking
# 76      NASDAQ NMS - GLOBAL MARKET                             NaN
# 303  NEW YORK STOCK EXCHANGE, INC.            Electrical Equipment
# 395  NEW YORK STOCK EXCHANGE, INC.            Electrical Equipment
# 396  NEW YORK STOCK EXCHANGE, INC.                     Health Care
# 595  NEW YORK STOCK EXCHANGE, INC.                 Auto Components
# 72      NASDAQ NMS - GLOBAL MARKET  Hotels Restaurants and Leisure
# 313  NEW YORK STOCK EXCHANGE, INC.                       Beverages
#
#                                                   logo  \
# 655  https://static.finnhub.io/logo/09caf854-81d9-1...
# 704  https://static.finnhub.io/logo/f0d5c3ba-80eb-1...
# 228  https://static.finnhub.io/logo/1ab22e6c-80e1-1...
# 76                                                 NaN
# 303  https://static.finnhub.io/logo/ec2c31c6-80eb-1...
# 395  https://static.finnhub.io/logo/81c63b2c-80ec-1...
# 396  https://static4.finnhub.io/file/publicdatany2/...
# 595  https://static.finnhub.io/logo/c558526758aff6a...
# 72   https://static.finnhub.io/logo/60068062-80db-1...
# 313  https://static.finnhub.io/logo/12f0377a-80ec-1...
#
#                                    weburl environment_grade environment_level  \
# 655               https://polarpower.com/                 B            Medium
# 704  https://www.graniteconstruction.com/                 B            Medium
# 228            https://www.zionsbank.com/                 B            Medium
# 76                                    NaN                 B            Medium
# 303              https://www.corning.com/                 B            Medium
# 395                   https://www.te.com/                 B            Medium
# 396             https://www.teleflex.com/                 B            Medium
# 595                  https://xlfleet.com/                 B            Medium
# 72       https://ir.alliedesportsent.com/                 B            Medium
# 313     https://www.coca-colacompany.com/                 B            Medium
#
#     social_grade  ... governance_grade governance_level environment_score  \
# 655            B  ...                B           Medium               200
# 704            B  ...                B           Medium               200
# 228            B  ...                B           Medium               200
# 76             B  ...                B           Medium               200
# 303            B  ...                B           Medium               200
# 395            B  ...                B           Medium               200
# 396            B  ...                B           Medium               200
# 595            B  ...                B           Medium               200
# 72             B  ...                B           Medium               200
# 313            B  ...                B           Medium               200
#
#      social_score  governance_score  total_score  last_processing_date  \
# 655           200               200          600            05-06-2022
# 704           200               200          600            07-11-2022
# 228           200               200          600            20-04-2022
# 76            200               200          600            21-06-2022
# 303           200               200          600            16-04-2022
# 395           200               200          600            19-04-2022
# 396           200               200          600            19-04-2022
# 595           200               200          600            22-04-2022
# 72            200               200          600            10-06-2022
# 313           201               200          601            16-04-2022
#
#     total_grade total_level      cik
# 655           B      Medium  1622345
# 704           B      Medium   861459
# 228           B      Medium   109380
# 76            B      Medium  1841661
# 303           B      Medium    24741
# 395           B      Medium  1385157
# 396           B      Medium    96943
# 595           B      Medium  1772720
# 72            B      Medium  1708341
# 313           B      Medium    21344
#
# [10 rows x 21 columns]

# %%
esg_data.count()
#wont need to show this for final, data will have been cleaned
# Out:
# ticker                  722
# name                    722
# currency                722
# exchange                722
# industry                709
# logo                    702
# weburl                  706
# environment_grade       722
# environment_level       722
# social_grade            722
# social_level            722
# governance_grade        722
# governance_level        722
# environment_score       722
# social_score            722
# governance_score        722
# total_score             722
# last_processing_date    722
# total_grade             722
# total_level             722
# cik                     722
# dtype: int64

# %%
esg_data.nunique()
#wont need to show this for final, data will have been cleaned
# Out:
# ticker                  722
# name                    722
# currency                  5
# exchange                  2
# industry                 47
# logo                    702
# weburl                  706
# environment_grade         5
# environment_level         3
# social_grade              6
# social_level              4
# governance_grade          4
# governance_level          3
# environment_score       197
# social_score            186
# governance_score         80
# total_score             441
# last_processing_date     30
# total_grade               4
# total_level               2
# cik                     722
# dtype: int64

# %%
# Dataframe Groupby "Industry" and ran .agg to gather statistics by industry
esg_industry_agg = esg_data.groupby(["industry"])["total_score"].agg(("mean", "median", "var", "std", "sem"))
esg_industry_counts = esg_data.groupby(["industry"])["total_score"].value_counts()
esg_industry_agg["# of companies"] = esg_data.groupby(["industry"])["total_score"].count()
esg_industry_agg
# Out:
#                                            mean  median            var  \
# industry
# Aerospace & Defense                  633.000000   633.0            NaN
# Aerospace and Defense               1089.700000  1136.0   24886.011111
# Airlines                             838.714286   746.0   36032.904762
# Auto Components                      833.333333   696.0  105349.333333
# Automobiles                          859.250000   873.0   42856.250000
# Banking                              898.310345   886.0   33559.507389
# Beverages                           1061.000000  1113.0  115992.000000
# Biotechnology                        866.910714   822.5   31003.610065
# Building                            1074.200000  1123.5   40144.400000
# Chemicals                           1058.894737  1132.0   55246.654971
# Commercial Services and Supplies     995.857143  1100.0   61514.476190
# Communications                       938.222222  1015.0   39169.444444
# Construction                        1082.666667  1187.5   61952.666667
# Consumer products                    945.550000   959.0   55428.997368
# Distributors                        1109.666667  1120.0    1640.333333
# Diversified Consumer Services        739.333333   698.0   24385.333333
# Electrical Equipment                 933.000000   937.0   50722.846154
# Energy                              1142.263158  1151.0   46887.204678
# Energy                               885.000000   885.0    8712.000000
# Financial Services                   909.333333   969.0   52359.354167
# Food Products                       1131.071429  1127.0    9614.994505
# Health Care                          938.764706  1011.0   49017.503529
# Hotels Restaurants and Leisure       918.863636   945.5   71464.504329
# Hotels, Restaurants & Leisure        746.000000   746.0   18818.000000
# Industrial Conglomerates            1157.000000  1141.0    1216.000000
# Insurance                           1012.370370  1077.0   29249.472934
# Leisure Products                     780.000000   827.0   11557.000000
# Beverages                           340.575983  170.287991               4
# Chemicals                           235.046070   53.923267              19
# Machinery                           171.987347   37.530716              21
# Professional Services               156.222521   59.046563               7
# Technology                          196.083246   24.704167              63
# Semiconductors                      164.422816   33.562667              24
# Metals and Mining                   258.710746   86.236915               9
# Logistics and Transportation        181.029740   73.905082               6
# Insurance                           171.024773   32.913733              27
# Real Estate                         230.277590   38.379598              36
# Commercial Services and Supplies    248.021120   93.743172               7
# Life Sciences Tools and Services    188.498939   47.124735              16
# Consumer products                   235.433637   52.644562              20
# Textiles Apparel and Luxury Goods   185.154740   61.718247               9
# Health Care                         221.398969   31.002057              51
# Communications                      197.912719   65.970906               9
# Media                               171.854383   35.834116              23
# Electrical Equipment                225.217331   43.343096              27
# Telecommunication                   227.062400  131.094538               3
# Hotels Restaurants and Leisure      267.328458   56.994619              22
# Retail                              229.917233   45.090479              26
# Financial Services                  228.821665   39.832739              33
# Pharmaceuticals                     217.728807   47.512321              21
# Banking                             183.192542   34.018001              29
# Trading Companies and Distributors  202.607256   90.608719               5
# Energy                               93.338095   66.000000               2
# Biotechnology                       176.078420   23.529469              56
# Marine                              191.586360  110.612437               3
# Automobiles                         207.017511  103.508756               4
# Airlines                            189.823351   71.746483               7
# Auto Components                     324.575620  187.393822               3
# Leisure Products                    107.503488   62.067168               3
# Hotels, Restaurants & Leisure       137.178716   97.000000               2
# Diversified Consumer Services       156.158040   90.157886               3
# Aerospace & Defense                        NaN         NaN               1
# Metals & Mining                            NaN         NaN               1

# %%
#Note for presentation we removed industries with less than 10 companies

esg_stats_refined = esg_stats_sorted[(esg_stats_sorted["# of companies"]>=10)]
esg_stats_refined.head(10)
# Out:
#                               mean  median           var         std  \
# industry
# Utilities              1190.633333  1199.5  35381.067816  188.098559
# Energy                 1142.263158  1151.0  46887.204678  216.534535
# Food Products          1131.071429  1127.0   9614.994505   98.056078
# Aerospace and Defense  1089.700000  1136.0  24886.011111  157.753007
# Building               1074.200000  1123.5  40144.400000  200.360675
# Chemicals              1058.894737  1132.0  55246.654971  235.046070
# Machinery              1048.047619  1125.0  29579.647619  171.987347
# Technology             1031.317460  1103.0  38448.639529  196.083246
# Semiconductors         1030.583333  1100.0  27034.862319  164.422816
# Insurance              1012.370370  1077.0  29249.472934  171.024773
#
#                              sem  # of companies
# industry
# Utilities              34.341941              30
# Energy                 49.676429              19
# Food Products          26.206589              14
# Aerospace and Defense  49.885881              10
# Building               63.359609              10
# Chemicals              53.923267              19
# Machinery              37.530716              21
# Technology             24.704167              63
# Semiconductors         33.562667              24
# Insurance              32.913733              27

# %%
avg_ESG_score_industry = esg_stats_refined["mean"]

avg_esg = avg_ESG_score_industry.plot(kind="bar", facecolor="blue", width=.75,
                                                  title="Top Average ESG Score by Industry",
                                                  figsize=(12,6),
                                                  xlabel="Industry",
                                                  ylabel="Average ESG Score")

# %%
bottom_esg_stats = esg_stats_refined.sort_values("mean", ascending=True)

bottom_esg_stats.head(10)
# Out:
#                                       mean  median           var         std  \
# industry
# Biotechnology                   866.910714   822.5  31003.610065  176.078420
# Banking                         898.310345   886.0  33559.507389  183.192542
# Pharmaceuticals                 903.666667   824.0  47405.833333  217.728807
# Financial Services              909.333333   969.0  52359.354167  228.821665
# Retail                          918.576923   948.0  52861.933846  229.917233
# Hotels Restaurants and Leisure  918.863636   945.5  71464.504329  267.328458
# Electrical Equipment            933.000000   937.0  50722.846154  225.217331
# Media                           935.260870   945.0  29533.928854  171.854383
# Health Care                     938.764706  1011.0  49017.503529  221.398969
# Consumer products               945.550000   959.0  55428.997368  235.433637
#
#                                       sem  # of companies
# industry
# Biotechnology                   23.529469              56
# Banking                         34.018001              29
# Pharmaceuticals                 47.512321              21
# Financial Services              39.832739              33
# Retail                          45.090479              26
# Hotels Restaurants and Leisure  56.994619              22
# Electrical Equipment            43.343096              27
# Media                           35.834116              23
# Health Care                     31.002057              51
# Consumer products               52.644562              20

# %%
esg_total_grades = esg_data.groupby(["total_grade"])["ticker"].count()
esg_total_grades_pie = esg_total_grades.plot(kind="pie", autopct='%1.1f%%', explode=[0.025, 0.025, 0.025, 0.025],
                                                  figsize=(12,6), title="ESG Total Rating Grades")

# %%
esg_enviro_grades = esg_data.groupby(["environment_grade"])["ticker"].count()
esg_enviro_grades_pie = esg_enviro_grades.plot(kind="pie", autopct='%1.1f%%', explode=[0.025, 0.025, 0.025, 0.025, 0.025],
                                                  figsize=(12,6), title="ESG Environmental Rating Grades")

# %%
# At this point, what I think we should do is bring in the clean dataset and run scatter plots of 
#Total score vs EPS
#Total score vs 5 year annualized % change

#just scatter plots

# %%
# Build scatter plot for Total ESG score vs. Annualized 5 yr % change
esg_complete.plot(kind="scatter", x="total_score", y="Annualized % Change", title="Total ESG score vs. Annualized 5 yr % change")


# Save the figure
#plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build scatter plot for Total ESG score vs. Annualized 5 yr % change
esg_complete.plot(kind="scatter", x="total_score", y="AVG Annual EPS", title="Total ESG score vs. AVG Annual EPS")


# Save the figure
#plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
perc_change_series= pd.DataFrame(esg_complete["Annualized % Change"])

# Create a boxplot for the data
plt.boxplot(perc_change_series)

# Add labels to the x-axis
plt.xticks([1], ['Annualized % Change'])

# Add a title and labels
plt.title('Title')
plt.ylabel('label')

# Show the plot
plt.show()

# %%
eps_series= pd.DataFrame(esg_complete["AVG Annual EPS"])
eps_series

#not sure why NaN is showing
# Out:
#      AVG Annual EPS
# 0             3.492
# 1             6.302
# 2            23.924
# 3            11.146
# 4            -1.818
# ..              ...
# 594           3.250
# 595             NaN
# 596          -1.744
# 597           1.678
# 598           2.474
#
# [599 rows x 1 columns]

# %%
eps_series= pd.DataFrame(esg_complete["AVG Annual EPS"])

# Create a boxplot for the data
plt.boxplot(eps_series)

# Add labels to the x-axis
#plt.xticks([1], ["AVG Annual EPS"])

# Add a title and labels
#plt.title('Title')
#plt.ylabel('label')

# Show the plot
plt.show()

# %%
#Eliminate the outliers

# %%
quartiles = perc_change_series.quantile([.25,.5,.75])
quartiles
# Out:
#       Annualized % Change
# 0.25            -2.039333
# 0.50             6.158378
# 0.75            17.905116

# %%
upperq = quartiles[0.75]
iqr = upperq-lowerq
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

outliers = []

for value in perc_change_series:

    if value < lower_bound: 
        outliers.append()
    elif value > upper_bound:
        outliers.append()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0.75
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 upperq = quartiles[0.75]
#       2 iqr = upperq-lowerq
#       3 lower_bound = lowerq - (1.5*iqr)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 0.75

# %%
#Followed by the regression, which should look at least a little better and have more meaningful stats

# %%
# Define a function to create Linear Regression plots
def linear_regression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation is: {round(correlation[0],2)}")
    print(f"The r-squared is: {rvalue**2}")
    print(f"the p-value is : {pvalue}")
    plt.show()

# %%
# Linear regression on Annualized % Change
plt.title("Title")
plt.xlabel("Total Score")
plt.ylabel("Annualized % Change") 
linear_regression(esg_complete["total_score"], esg_complete["Annualized % Change"])
# Out:
# The correlation is: 0.01
# The r-squared is: 4.561032844140758e-05
# the p-value is : 0.8689864661233195

# %%
# Linear regression on AVG Annual EPS
plt.title("Title")
plt.xlabel("Total Score")
plt.ylabel("AVG Annual EPS") 
linear_regression(esg_complete["total_score"], esg_complete["AVG Annual EPS"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 5
#       3 plt.xlabel("Total Score")
#       4 plt.ylabel("AVG Annual EPS")
# ----> 5 linear_regression(esg_complete["total_score"], esg_complete["AVG Annual EPS"])
#
# Cell In[22], line 9, in linear_regression(x_values, y_values)
#       7 plt.plot(x_values,regress_values,"r-")
#       8 plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
# ----> 9 correlation = st.pearsonr(x_values,y_values)
#      10 print(f"The correlation is: {round(correlation[0],2)}")
#      11 print(f"The r-squared is: {rvalue**2}")
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4838, in pearsonr(x, y, alternative, method)
#    4834 # Unlike np.linalg.norm or the expression sqrt((xm*xm).sum()),
#    4835 # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    4836 # [-5e210, 5e210, 3e200, -3e200]
#    4837 normxm = linalg.norm(xm)
# -> 4838 normym = linalg.norm(ym)
#    4840 threshold = 1e-13
#    4841 if normxm < threshold*abs(xmean) or normym < threshold*abs(ymean):
#    4842     # If all the values in x (likewise y) are very close to the mean,
#    4843     # the loss of precision that occurs in the subtraction xm = x - xmean
#    4844     # might result in large errors in r.
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/linalg/_misc.py:146, in norm(a, ord, axis, keepdims, check_finite)
#     144 # Differs from numpy only in non-finite handling and the use of blas.
#     145 if check_finite:
# --> 146     a = np.asarray_chkfinite(a)
#     147 else:
#     148     a = np.asarray(a)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/numpy/lib/function_base.py:630, in asarray_chkfinite(a, dtype, order)
#     628 a = asarray(a, dtype=dtype, order=order)
#     629 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 630     raise ValueError(
#     631         "array must not contain infs or NaNs")
#     632 return a
#
# ValueError: array must not contain infs or NaNs
